# %%
import matplotlib.pyplot as plot

# allow plots to show in Jupyter Notebook
# %matplotlib inline
 
import numpy as np
import pandas as pd

# Autoreload notebook when changes are made
# %reload_ext autoreload
# %autoreload

# %%
# Create x and y arrays
# x1 = Create an array of 10 floats from 0 to 5
x1 = np.linspace(0, 5, 10)
y1 = x1**2

plot.plot(x1,y1) # Display plot
plot.title("x² Graph")  # Plot title

plot.xlabel("x")
plot.ylabel("x²")
# Out:
# Text(0, 0.5, 'x²')

# %%
plot.subplot(1, 2, 1)  # (row, column, plot num)
plot.plot(x1, y1, "r") # "r" - make plot line red

plot.subplot(1, 2, 2)
plot.plot(x1, y1, "b")

# %%
# Figure objects contain all plot elements
# Can hold many axes objects, but a given axes object can only exist in one figure
# Figure is essentially the paper, axes are the graphs or plotlines

# figsize = define width and height in inches
# dpi = res of figure in dots per inch
fig1 = plot.figure(figsize=(5,4), dpi=100)

# add an axes object with [left, bottom, width, height] in range 0-1
axis1 = fig1.add_axes([0.1, 0.1, 0.9, 0.9])

axis1.set_xlabel("x")
axis1.set_ylabel("y")
axis1.set_title("x² graph")

# Display plot on the axes
axis1.plot(x1, y1, label = "x/x²")

# Second plotline on the same axes
axis1.plot(y1, x1, label = "x²/x")

# Add optional legend with location number
# best guess: 0, upper right: 1, upper left: 2, lower left: 3, lower right: 4
# 0 makes it look for locations with minimal overlap. Might lead to slowdown on complex graphs
axis1.legend(loc=0)

# Create a second axis inside the figure
axis2 = fig1.add_axes([0.45,0.45,0.4,0.3])
axis2.set_xlabel("x")
axis2.set_ylabel("y")
axis2.set_title("Small x² graph")
axis2.plot(x1,y1,"r")

# Add text to plot (x, y, "text")
# (0,0) is the centre of the figure
axis2.text(0, 40, 'Message')
# Out:
# Text(0, 40, 'Message')

# %% [markdown]
# Subplots

# %%
# How to define multiple plots with subplots
# axis2 is a list of generated axes objects
# create a set of subplots based on nrows,ncols
# can assign shared values between plots
fig2, axis2 = plot.subplots(figsize= (8,4), nrows=1, ncols=3)
plot.tight_layout() # generate space between plots

# access the different axes objects with list indices
axis2[0].set_title("Plot 1")
axis2[1].set_title("Plot 2")
axis2[2].set_title("Plot 3")

axis2[1].set_xlabel("x")
axis2[1].set_ylabel("x²")
axis2[1].plot(x1,y1)

# %% [markdown]
# Controlling the Appearance

# %%
fig3 = plot.figure(figsize=(6,4))
axis3 = fig3.add_axes([0,0,1,1])

# Default colours = blue(b), green(g), red(r), cyan(c), magenta(m), yellow(y), black(k), white(w)
# color="0.75" - mix with 75% grey
# Can use hexcode or dulux colour names like limegreen or royalblue
# https://en.wikipedia.org/wiki/Web_colors
# aplha variable defines opacity
# lw = line width. default 1
# Line styles - matplotlib.org/3.1.0/gallery/lines_bars_and_markers/linestyles.html

# Markers - exactly what it sounds like - https://matplotlib.org/3.3.0/api/markers_api.html
# markerfacecolor - fill colour
# markeredgecolor - stroke colour
# markeredgewidth - stroke size

axis3.plot(x1,y1,color='navy', alpha=.75, lw=2, ls='-.',
           marker='o', markersize=7, markerfacecolor='y',
           markeredgecolor='y', markeredgewidth=4)

# Set bounds
axis3.set_xlim([0,3])
axis3.set_ylim([0,8])

# add grid, colour, dashes
axis3.grid(True, color="0.6", dashes=(5,2,1,2))
axis3.set_facecolor("#cdf2cc")

# %% [markdown]
# Save Graph to a file

# %%
fig3.savefig("fig3.png")

# %% [markdown]
# Pandas DataFrame

# %%
# read a csv file
from sre_parse import fix_flags


ics_df = pd.read_csv("icecreamsales.csv")
ics_df = ics_df.sort_values(by="Temperature")

# convert pandas to numpy array
np_array = ics_df.values
#print(np_array)

# get x, y values in an array
x2 = np_array[:,0]
y2 = np_array[:,1]

fig4 = plot.figure(figsize=(6,4))
axis4 = fig4.add_axes([0,0,1,1])
axis4.set_title("Sales vs Temperature")
axis4.set_xlabel("Temperature")
axis4.set_ylabel("Sales")
axis4.plot(x2,y2)

# adding annotations
axis4.annotate('Good Month', xy=(83, 536), xytext=(60, 520),
             arrowprops=dict(facecolor='black', shrink=0.05),)

# add bars below each point
plot.bar(x2,y2)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# TeX Markup

# %%
# Using TeX markup
fig5 = plot.figure(figsize=(5,4), dpi=100)
axis5 = fig5.add_axes([0.1,0.1,0.9,0.9])

# # All listed plus kappa, iota, zeta, nu, rho, eta, xi, omicron, gamma, tau, phi, 
# chi, psi, delta (Capitalize the first letter for uppercase)
axis5.text(0, 23, 
            r'$\alpha \beta \sigma \omega \epsilon \mu \pi \theta \lambda$', fontsize=18)
# Subscripts, multiletter superscript, sum, fractions, binomial
axis5.text(0, 18, 
            r'$\delta_i \gamma^{ij} \sum_{i=0}^\infty x_i \frac{3}{4} \binom{3}{4}$', 
            fontsize=18)
# Another fraction, sqrt, cbrt, trig functions : 
axis5.text(0, 13, 
            r'$\frac{8 - \frac{x}{5}}{8} \sqrt{9} \sin(\pi) \sqrt[3]{8} \acute a \div$', 
            fontsize=18)
axis5.text(0, 8, 
            r'$\bar a \hat a \tilde a \vec a \overline {a} \lim_{x \to 2} f(x) = 5$', 
            fontsize=18)
axis5.text(0, 3, 
            r'$\geq \leq \ne$', 
            fontsize=18)
axis5.plot(x1,y1)

# %% [markdown]
# Histograms

# %%
# roll 2 6 sided dies and get the sum to plot the histogram

arr1 = np.random.randint(1,7,5000)
arr2 = np.random.randint(1,7,5000)
arr3 = arr1 + arr2

# bins - number of options available 2 through 12 = 11
# density returns the frequency of each bin
# range - tuple with bin range interested in
# cumulative - use a cumulative distrubution if set to true
# histtype - "step" generates a line plot
plot.hist(arr3, bins=11, density=True, stacked=True)
# Out:
# (array([0.03146, 0.05676, 0.08954, 0.1133 , 0.15818, 0.1859 , 0.14344,
#         0.12386, 0.10296, 0.06138, 0.03322]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)

# %% [markdown]
# Bar Charts

# %%
# Analyse where France gets its electricity from
from turtle import color


x = ['Nuclear', 'Hydro', 'Coal', 'Gas', 'Solar', 'Wind', 'Other']
per_1 = [71, 10, 3, 7, 2, 4, 3]

variance = [8, 3, 1, 3, 1, 2, 1]

#barh results in horizontal chart
# yerr = takes in a list or int
plot.bar(x, per_1, color="purple", yerr=variance)
# Out:
# <BarContainer object of 7 artists>

# %%
# show percentage of gender in engineering
m_eng = (76, 85, 86, 88, 93)
f_eng = (24, 15, 14, 12, 7)

# get evenly spaced values for each interval
spc = np.arange(5)

plot.bar(spc, m_eng, width=0.45, label='Male', edgecolor='k')
plot.bar(spc + 0.45, f_eng, width=0.45, label='Female', edgecolor='k')

# define x tick names and places in middle of bars
plot.xticks(spc + 0.45 / 2, ('Aero', 'Chem', 'Civil', 'Elec', 'Mech'))
# Out:
# ([<matplotlib.axis.XTick at 0x1427fb50>,
#   <matplotlib.axis.XTick at 0x1427fb20>,
#   <matplotlib.axis.XTick at 0x1427f2b0>,
#   <matplotlib.axis.XTick at 0x13b64820>,
#   <matplotlib.axis.XTick at 0x13b83040>],
#  [Text(0.225, 0, 'Aero'),
#   Text(1.225, 0, 'Chem'),
#   Text(2.225, 0, 'Civil'),
#   Text(3.225, 0, 'Elec'),
#   Text(4.225, 0, 'Mech')])

# %%
# Plot teachers by sex
t_type = ['Kind', 'Elem', 'Sec', 'Spec']
m_teach = np.array([2, 20, 44, 14])
f_teach = np.array([98, 80, 56, 86])
index = [x for x, y in enumerate(t_type)]

# Plot stacked bars for men and then women under
plot.bar(index, m_teach, width=0.45, label='Male', bottom=f_teach)
plot.bar(index, f_teach, width=0.45, label='Female')

plot.legend(loc='lower right')

# %% [markdown]
# Pie Charts

# %%
import random

fig6 = plot.figure(figsize=(8,5), dpi=100)
axis6 = fig6.add_axes([0.1,0.1,0.9,0.9])

# Create a pie chart of the number of Pokemon by type
types = ['Water', 'Normal', 'Flying', 'Grass', 'Psychic', 'Bug', 'Fire', 'Poison',
'Ground', 'Rock', 'Fighting', 'Dark', 'Steel', 'Electric', 'Dragon', 'Fairy',
'Ghost', 'Ice']
poke_num = [133, 109, 101, 98, 85, 77, 68, 66, 65, 60, 57, 54, 53, 51, 50, 50, 46, 40]

# generate random colour array
colours = []
for i in range(18):
    rgb = (random.uniform(0, 0.5), random.uniform(0, 0.5), random.uniform(0, 0.5))
    colours.append(rgb)

    explode = [0] * 18
    explode[0] = 0.2

    # provide values, what to explode, labels, colours, pct for values
    # shadows, amount to rotate, pie text colour

wedges, texts, autotexts = plot.pie(poke_num, explode=explode, labels=types, colors=colours, 
                                   autopct='%1.0f%%', shadow=True, startangle=140, 
                                   textprops=dict(color="w"))

plot.legend(wedges, types, loc="right", bbox_to_anchor= (1,0,0.5,1))

# %% [markdown]
# Plot Timesereies

# %%
import datetime

# get yahoo goog csv file and convert to numpy array
goog_data = pd.read_csv("GOOG.csv")
goog_data_np = goog_data.to_numpy()
# get 5th column which is prices
goog_cp = goog_data_np[:,4]
goog_cp

# Get NumPy array with just weekdays between dates excluding holidays
# holidays parameter excludes certain dates
# freq = B default which is business days, C is custom business days
holidays = [datetime.datetime(2020,5,25), datetime.datetime(2020,8,19)]
date_arr = pd.bdate_range(start='5/20/2020', end='8/19/2020', 
                          freq='C',
                         holidays=holidays)
date_arr_np = date_arr.to_numpy()

fig_7 = plot.figure(figsize=(8,5),dpi=100)
axes_7 = fig_7.add_axes([0.1,0.1,0.9,0.9])
plot.plot(date_arr_np, goog_cp)

# %% [markdown]
# Tables

# %%
# format column data to 2 decimals
goog_data['Open'] = pd.Series([round(val, 2) for val in goog_data['Open']], 
                              index = goog_data.index)
goog_data['High'] = pd.Series([round(val, 2) for val in goog_data['High']], 
                              index = goog_data.index)
goog_data['Low'] = pd.Series([round(val, 2) for val in goog_data['Low']], 
                              index = goog_data.index)
goog_data['Close'] = pd.Series([round(val, 2) for val in goog_data['Close']], 
                              index = goog_data.index)
goog_data['Adj Close'] = pd.Series([round(val, 2) for val in goog_data['Adj Close']], 
                              index = goog_data.index)

# get last 5 days of stock data
stock_data = goog_data[-5:]
stock_data

# define headers
col_head = ('Date','Open','High','Low','Close','Adj Close','Volume')

stock_data_np = stock_data.to_numpy()
stock_data_np

# Add padding around cells in table
plot.figure(linewidth=2, tight_layout={'pad':.5}, figsize=(5,3))

# Get rid of axes and plot box
axes_8 = plot.gca()
axes_8.get_xaxis().set_visible(False)
axes_8.get_yaxis().set_visible(False)
plot.box(on=None)

# np.full returns an array filled with 0.1
# cm is a colormap object we are using to use a default blue color
# matplotlib.org/3.1.0/tutorials/colors/colormaps.html
ccolors = plot.cm.Blues(np.full(len(col_head), 0.2))

# Receives data, loc, list of column headers, column header color as array of colors
# You can also add rowLabel, rowColours, rowLoc: Text alignment
the_table = plot.table(cellText=stock_data_np, loc='center', colLabels=col_head,
                     colColours=ccolors)
# Set table font size
the_table.set_fontsize(14)
the_table.scale(3, 2.5)
# Out:
# C:\Users\vabhi\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Scatter Plots

# %%
# Country array
cnt_arr = np.array(['Australia','Brazil','Canada','Chile','France','Germany','Greece',
                   'Iceland','India','Iran','Italy','Mexico','New Zealand','Nigeria',
                   'Norway','Pakistan','Peru','Russia','Saudi Arabia','Singapore',
                   'South Africa','Spain','Sweden','Turkey','UK','US'])

# Death rate per 100k Coronavirus
dr_arr = np.array([1.8,53,24.5,56.5,45.4,11.2,2.2,
                   2.8,4,24.6,58.6,46.3,.5,.5,
                   4.9,2.9,83.3,11,10.4,.5,
                   21.5,61.6,56.9,7.3,62.4,52.9])

# Daily confirmed cases (Tests)
test_arr = np.array([110,7197,600,1862,1636,1103,35,
                   10,295,1658,1226,2490,8,243,
                   48,1395,1101,4447,1443,280,
                   2830,1602,447,1205,1546,24988])

# Dot size Confirmed cases
cc_arr = np.array([24236,3456652,125408,390037,256534,229706,7684,
                   2035,2836925,350279,255278,537031,1654,50488,
                   10162,290445,549321,935066,302686,56031,
                   596060,370867,85411,253108,323008,5529824])
cc_arr_sm = cc_arr / 1000
color_arr = np.random.rand(26)

plot.title('Death Rate per 100k vs. Confirmed Cases')
plot.xlabel('Death Rate per 100k')
plot.ylabel('Confirmed Cases')
plot.scatter(dr_arr,test_arr,s=cc_arr_sm,c=color_arr,alpha=0.5)

# %% [markdown]
# 3D Surfaces

# %%
# Needed for creating 3D axes
from mpl_toolkits import mplot3d

fig_9 = plot.figure(figsize=(8,5),dpi=100)
axes_9 = fig_9.add_axes([0.1,0.1,0.9,0.9], projection='3d')

# Create a 3D scatterplot
# The darker points are represented that way to seem closer to you
z_3 = 15 * np.random.random(100)
x_3 = np.sin(z_3) * np.random.randn(100)
y_3 = np.cos(z_3) * np.random.randn(100)
# axes_9.scatter3D(x_3, y_3, z_3, c=z_3, cmap='Blues')

# You can create contour plots by defining a function for z based on x & y
def get_z(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

x_4 = np.linspace(-6, 6, 30)
y_4 = np.linspace(-6, 6, 30)

# Creates a rectangular grid out of 2 given 1D arrays
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = get_z(x_4,y_4)

# Change viewing angle to reorient camera 60 degrees and rotate 55
axes_9.view_init(45,55)

# Provide x, y, z, contours and color map
# axes_9.contour3D(x_4,y_4,z_4,80,cmap='Blues')
axes_9.set_xlabel('x')
axes_9.set_ylabel('y')
axes_9.set_zlabel('z')

# You can create wireframes
# axes_9.plot_wireframe(x_4,y_4,z_4,color='blue')

# You can create surface plots which is wireframe with filled faces
axes_9.plot_surface(x_4,y_4,z_4, rstride=1, cstride=1,cmap='Blues',edgecolor='none')

# %% [markdown]
# MPL Finance

# %%
# We need this module to handle the calculations
import mplfinance as mpf

# Get stock data as DataFrame and define index
goog_df = pd.read_csv('GOOG.csv',index_col=0,parse_dates=True)
goog_df.index.name = 'Date'

goog_df.shape

# A candlestick chart demonstrates the daily open, high, low and closing price of a stock
# mpf.plot(goog_df,type='candle')

# Plot price changes
#mpf.plot(goog_df,type='line')

# Moving averages provide trend information (Average of previous 4 observations)
#mpf.plot(goog_df,type='ohlc',mav=4)

# You can plot multiple MAVs, volume, non-trading days
mpf.plot(goog_df,type='ohlc',mav=(3,5,7),volume=True,show_nontrading=True)

# %% [markdown]
# Heatmaps

# %%
# A heatmap is a color coded representation of data from a 2D list
symptoms = ["Coronavirus","Influenza","Pneumonia","Dyspnea"]
dates = ["Jun28","Jul05","Jul12","Jul19","Jul26","Aug02","Aug09","Aug16","Aug21"]
symp_per = np.array([[5.2, 5.5, 5.7, 5.6, 5.3, 5.1, 5.0, 4.9, 5.3],
                    [3.5, 4.0, 4.3, 3.9, 3.5, 3.2, 2.7, 2.2, 2.0],
                    [1.8, 2.2, 2.3, 2.2, 2.1, 1.9, 1.7, 1.4, 1.3],
                    [1.0, 1.1, 1.1, 1.0, 0.9, 0.8, 0.8, 0.8, 0.7]])

fig_10, axes_10 = plot.subplots()
# Dfine data to use and color map
im = axes_10.imshow(symp_per, cmap="Wistia")

# Add ticks at data points and labels
axes_10.set_xticks(np.arange(len(dates)))
axes_10.set_yticks(np.arange(len(symptoms)))
axes_10.set_xticklabels(dates)
axes_10.set_yticklabels(symptoms)

# Rotate labels on the bottom so they don't overlap
plot.setp(axes_10.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(symptoms)):
    for j in range(len(dates)):
        text = axes_10.text(j, i, symp_per[i, j],
                       ha="center", va="center", color="k",fontweight="bold")
